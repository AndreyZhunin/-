# %%
t = input()
file = open(t, 'r', encoding='utf-8')
print(file.read())
file.close()

# %%
t = input()
file = open(t, 'r', encoding='utf-8')
stroki = languages = file.readlines()
print(stroki[-2].rstrip())
file.close()
