# %%
def draw_box():
    for _ in range(5):
        print('*' * 7)
draw_box()
# Out:
# *******
# *******
# *******
# *******
# *******

# %%
# объявление функции
def print_message():
    print('Я - Артур,')
    print('король британцев. ')


# вызов функции
print_message()
# Out:
# Я - Артур,
# король британцев.

# %%
def do_nothing():    #Заглушка
    pass

# %%
def draw_box(height, width):    # функция принимает два параметра
    for i in range(height):
        print('*' * width)
print(draw_box(int(input()), int(input())))
# Out:
# *****
# *****
# *****
# *****
# *****
# None
