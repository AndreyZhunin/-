# %%
num1 = int(input())
num2 = int(input())

if num1 < num2:
    print(num1, 'меньше чем', num2)
if num1 > num2:
    print(num1, 'больше чем', num2)
if num1 == num2:                      # используем двойное равенство
    print(num1, 'равно', num2)
if num1 != num2:
    print(num1, 'не равно', num2)
# Out:
# 4 меньше чем 5
# 4 не равно 5

# %%
age = int(input())
if 3 <= age <= 6:
    print('Вы ребёнок')
# Out:
# Вы ребёнок

# %%
a = int(input())
b = int(input())
c = int(input())
if a == b == c:
    print('числа равны')
else:
    print('числа не равны')
# Out:
# числа не равны

# %%
world = input()
if world == "Python":
    print("Да")
else:
    print("Нет")
# Out:
# Да

# %%
num = int(input())
a = num%10
b = num//10
if a == b:
    print("Да")
else:
    print("Нет")
# Out:
# Да

# %%
num1, num2, num3 = int(input()), int(input()), int(input())
counter = 0  # переменная счётчик
if num1 % 2 == 0:
    counter = counter + 1  # увеличиваем счётчик на 1
if num2 % 2 == 0:
    counter = counter + 1  # увеличиваем счётчик на 1
if num3 % 2 == 0:
    counter = counter + 1  # увеличиваем счётчик на 1
print(counter)
# Out:
# 1

# %%
a = input()
b = input()
if a == b:
    print ("Пароль принят")
else:
    print ("Пароль не принят")
# Out:
# Пароль принят

# %%
num = int(input())
a = num%2
if a == 0:
    print("Четное")
if a != 0:
    print("Нечетное")
# Out:
# Нечетное

# %%
num = int(input())
a = num//1000
b = num%1000//100
c = num%100//10
d = num%10
if a+d == b-c:
    print("ДА")
if a+d != b-c:
    print("НЕТ")
# Out:
# ДА

# %%
age = int(input())
if age >= 18:
    print("Доступ разрешен")
if age < 18:
    print("Доступ запрещен")
# Out:
# Доступ разрешен

# %%
a = int(input())
b = int(input())
c = int(input())
if c-b == b-a:
    print("YES")
if c-b != b-a:
    print("NO")
# Out:
# YES

# %%
a = int(input())
b = int(input())
if a > b:
    print(b)
if a < b:
    print(a)
# Out:
# 22

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if a < b and a < c and a < d:
    print(a)
if b < a and b < c and b < d:
    print(b)
if c < a and c < b and c < d:
    print(c)
if d < a and d < b and d < c:
    print(d)
# Out:
# 2

# %%
a = int(input())
b = int(input())
c = int(input())
d = int(input())
if a<b:
    AB = a
else:
    AB = b
if c<d:
    CD = c
else:
    CD = d
if AB<CD:
    print(AB)
else:
    print(CD)
# Out:
# 5

# %%
a = int(input())
if a<=13:
    print("детство")
if 14<=a<=24:
    print("молодость")
if 25<=a<=59:
    print("зрелость")
if a>=60:
    print("старость")
# Out:
# детство

# %%
a = int(input())
b = int(input())
c = int(input())
if a>0:
    d = a
else:
    d = 0
if b>0:
    e = b
else:
    e = 0
if c>0:
    f = c
else:
    f=0
z = d+e+f
print(z)
# Out:
# 0

# %%
x = int(input())
if -1<x<17:
    print("Принадлежит")
else:
    print("Не принадлежит")
# Out:
# Не принадлежит

# %%
x = int(input())
if x<=-3 or x>=7:
    print("Принадлежит")
else:
    print("Не принадлежит")
# Out:
# Не принадлежит

# %%
x = int(input())
if -30<x<=-2 or 7<x<=25:
    print("Принадлежит")
else:
    print("Не принадлежит")
# Out:
# Не принадлежит

# %%
x = int(input())
if 1000<=x<=9999 and (x%7==0 or x%17==0):
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
a = int(input())
b = int(input())
c = int(input())
if a<b+c and b<a+c and c<a+b:
    print("YES")
else:
    print("NO")

# %%
x = int(input())
if x%4==0 and x%100!=0 or x%400==0:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
a = int(input())     #Столбец в 1й клетке
b = int(input())     #Строка во 1й клетке
c = int(input())     #Столбец в 2й клетке
d = int(input())     #Строка во 2й клетке
if a==c or b==d:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
a = int(input())     #Столбец в 1й клетке
b = int(input())     #Строка во 1й клетке
c = int(input())     #Столбец в 2й клетке
d = int(input())     #Строка во 2й клетке
if c==a+1 and d==b+1 or c==a-1 and d==b-1 or c==a-1 and d==b+1 or c==a+1 and d==b-1 or c==a+1 and d==b or d==b+1 and c==a or c==a-1 and d==b or d==b-1 and c==a:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
n = int(input())
k = int(input())
if n>k:
    print("NO")
elif n<k:
    print("YES")
else:
    print("Don't know")
# Out:
# Don't know

# %%
a = int(input())
b = int(input())
c = int(input())
if a==b!=c or a==c!=b or b==c!=a:
    print("Равнобедренный")
elif a!=b!=c:
    print("Разносторонний")
elif a==b==c:
    print("Равносторонний")

# %%
a = int(input())
b = int(input())
c = int(input())
if b>a>c or b<a<c:
    print(a)
elif a>b>c or a<b<c:
    print(b)
elif a>c>b or a<c<b:
    print(c)

# %%
a = int(input())
if a==1 or a==3 or a==5 or a==7 or a==8 or a==10 or a==12:
    print("31")
elif a==4 or a==6 or a==9 or a==11:
    print("30")
elif a==2:
    print("28")

# %%
a = int(input())
if a<60:
    print("Легкий вес")
elif 60<=a<64:
    print("Первый полусредний вес")
elif 64<=a<69:
    print("Полусредний вес")
# Out:
# Первый полусредний вес

# %%
a = int(input())
b = int(input())
c = input()
if c=="*" or c=="/" or c=="-" or c=="+":
    if c=="*":
        print(a*b)
    elif c=="/":
        if b==0:
            print("На ноль делить нельзя!")
        else:
            print(a/b)
    elif c=="+":
        print(a+b)
    elif c=="-":
        print(a-b)
else:
    print("Неверная операция")
# Out:
# На ноль делить нельзя!

# %%
a = input()
b = input()
if a=="красный" or a=="синий" or a=="желтый":
    if b=="красный" or b=="синий" or b=="желтый":
        if a=="красный" and b=="красный":
            print("красный")
        elif a=="красный" and b=="синий":
            print("фиолетовый")
        elif a=="красный" and b=="желтый":
            print("оранжевый")
        elif a=="синий" and b=="синий":
            print("синий")
        elif a=="синий" and b=="желтый":
            print("зеленый")
        elif a=="синий" and b=="красный":
            print("фиолетовый")
        elif a=="желтый" and b=="желтый":
            print("желтый")
        elif a=="желтый" and b=="красный":
            print("оранжевый")
        elif a=="желтый" and b=="синий":
            print("зеленый")                        
    else:
        print("ошибка цвета")
else:
    print("ошибка цвета")

# %%
a = int(input())
if 0<=a<=36:
    if 1<=a<=10:
        if a==1 or a==3 or a==5 or a==7 or a==9:
            print("красный")
        elif a==2 or a==4 or a==6 or a==8 or a==10:
            print("черный")
    elif 11<=a<=18:
        if a==11 or a==13 or a==15 or a==17:
            print("черный")
        elif a==12 or a==14 or a==16 or a==18:
            print("красный")
    elif 19<=a<=28:
        if a==19 or a==21 or a==23 or a==25 or a==27:
            print("красный")
        elif a==20 or a==22 or a==24 or a==26 or a==28:
            print("черный")
    elif 29<=a<=36:
        if a==29 or a==31 or a==33 or a==35:
            print("черный")
        elif a==30 or a==32 or a==34 or a==36:
            print("красный")
    elif a==0:
        print("зеленый")
else:
    print("ошибка ввода")

# %%
a1 = int(input())
b1 = int(input())
a2 = int(input())
b2 = int(input())
if a1<a2 and b2<b1 or b1==b2 and a2>a1 or a1==a2 and b2<b1 or a1==a2 and b1==b2:
    print(a2, b2)
elif a1==a2 and b2>b1 or a2>a1 and b1==b2 or a2<a1 and b2>b1:
    print(a1, b1)
elif a2>a1 and b2>b1 and a2<b1:
    print(a2, b1)
elif a1>a2 and b1>b2 and b2>a1 and a1!=b2 or a1>a2 and b1==b2:
    print(a1, b2)
elif b1==a2:
    print(b1)
elif b2==a1:
    print(b2)
elif a2>a1 and b2>b1 or a1>a2 and b1>b2:
    print("пустое множество")
# Out:
# 10 -100

# %%
a = int(input())
b = a%10
c = a%100//10
d = a%1000//100
if b==c==0:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
a1 = int(input())
b1 = int(input())
a2 = int(input())
b2 = int(input())
if (a1+a2+b1+b2)%2==0:
    print("YES")
else:
    print("NO")

# %%
a = int(input())
b = input()
if 10<=a<=15 and b=="f":
    print("YES")
else:
    print("NO")

# %%
a = int(input())
if a==1:
    print("I")
elif a==2:
    print("II")
elif a==3:
    print("III")
elif a==4:
    print("IV")
elif a==5:
    print("V")
elif a==6:
    print("VI")
elif a==7:
    print("VII")
elif a==8:
    print("VIII")
elif a==9:
    print("IX")
elif a==10:
    print("X")
else:
    print("ошибка")

# %%
a = int(input())
if a%2!=0:
    print("YES")
elif 2<=a<=5 and a%2==0:
    print("NO")
elif 6<=a<=20 and a%2==0:
    print("YES")
elif a>20 and a%2==0:
    print("NO")
# Out:
# YES

# %%
a1 = int(input())
b1 = int(input())
a2 = int(input())
b2 = int(input())
if a1>a2 and b1>b2:
    y = a1-a2
    z = b1-b2
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1<a2 and b1<b2:
    y = a2-a1
    z = b2-b1
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1>a2 and b1<b2:
    y = a1-a2
    z = b2-b1
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1<a2 and b1>b2:
    y = a2-a1
    z = b1-b2
    if y==z:
        print("YES")
    else:
        print("NO")
else:
    print("NO")

# %%
x1 = int(input())
y1 = int(input())
x2 = int(input())
y2 = int(input())
if abs(x1 - x2) == abs(y1 - y2):
    print('YES')
else:
    print('NO')

# %%
x1 = int(input())
y1 = int(input())
x2 = int(input())
y2 = int(input())
if (abs(x1 - x2) == 2 and abs(y1 - y2) == 1) or (abs(x1 - x2) == 1 and abs(y1 - y2) == 2):
    print ("YES")
else:
    print ("NO")

# %%
x1 = int(input())
y1 = int(input())
x2 = int(input())
y2 = int(input())
if (abs(x1 - x2) == 2 and abs(y1 - y2) == 1) or (abs(x1 - x2) == 1 and abs(y1 - y2) == 2):
    print ("YES")
else:
    print ("NO")

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
if (abs(a-c)==abs(b-d)) or (a==c or b==d):
    print('YES')
else:
    print('NO')

# %%
a1 = int(input())
b1 = int(input())
a2 = int(input())
b2 = int(input())
if a1>a2 and b1>b2:
    y = a1-a2
    z = b1-b2
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1<a2 and b1<b2:
    y = a2-a1
    z = b2-b1
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1>a2 and b1<b2:
    y = a1-a2
    z = b2-b1
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1<a2 and b1>b2:
    y = a2-a1
    z = b1-b2
    if y==z:
        print("YES")
    else:
        print("NO")
elif a1==a2 or b1==b2:
    print("YES")
else:
    print("NO")

# %%
a1 = int(input())
b1 = int(input())
a2 = int(input())
b2 = int(input())
if a2==a1-2 and b2==b1+1:
    print("YES")
elif a2==a1-1 and b2==b1+2:
    print("YES")
elif a2==a1+1 and b2==b1+2:
    print("YES")
elif a2==a1+2 and b2==b1+1:
    print("YES")
elif a2==a1+2 and b2==b1-1:
    print("YES")
elif a2==a1+1 and b2==b1-2:
    print("YES")
elif a2==a1-1 and b2==b1-2:
    print("YES")
elif a2==a1-2 and b2==b1-1:
    print("YES")
else:
    print("NO")
